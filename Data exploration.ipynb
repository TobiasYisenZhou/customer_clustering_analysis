# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# %%
# loading all files and creating a united dataframe 
path = r'D:\CU\fall 2021\Practicum\data1' 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8930770 entries, 0 to 8930769
# Data columns (total 30 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   Unnamed: 0                                                int64
#  1   ZIP                                                       int64
#  2   TSP: Type of Match (Enhanced)                             object
#  3   Number of Children (Enhanced)                             float64
#  4   Family composition (Enhanced)                             float64
#  5   Gender code - Person 1                                    float64
#  6   Advantage Individual Marital Status - Person 1            float64
#  7   Advantage Individual Marital Status Indicator - Person 1  object
#  8   Person Sequence Number - Person 1                         object
#  9   Age in 2-year ranges - Person 1 (Enhanced)                float64
# ...

# %%
frame.head()
# Out:
#    Unnamed: 0    ZIP TSP: Type of Match (Enhanced)  \
# 0           0  20001                             A
# 1           1  20001                             A
# 2           2  20001                             A
# 3           3  20001                             A
# 4           4  20001                             A
#
#    Number of Children (Enhanced)  Family composition (Enhanced)  \
# 0                            NaN                           12.0
# 1                            NaN                           14.0
# 2                            NaN                            2.0
# 3                            NaN                            2.0
# 4                            NaN                           14.0
#
#    Gender code - Person 1  Advantage Individual Marital Status - Person 1  \
# 0                     1.0                                             2.0
# 1                     2.0                                             2.0
# ...

# %%
# dropping unwanted columns
#frame.drop(labels=["Unnamed: 0"],axis=1, inplace=True)
frame.reset_index()
frame.head()
# Out:
#    Unnamed: 0    ZIP TSP: Type of Match (Enhanced)  \
# 0           0  20001                             A
# 1           1  20001                             A
# 2           2  20001                             A
# 3           3  20001                             A
# 4           4  20001                             A
#
#    Number of Children (Enhanced)  Family composition (Enhanced)  \
# 0                            NaN                           12.0
# 1                            NaN                           14.0
# 2                            NaN                            2.0
# 3                            NaN                            2.0
# 4                            NaN                           14.0
#
#    Gender code - Person 1  Advantage Individual Marital Status - Person 1  \
# 0                     1.0                                             2.0
# 1                     2.0                                             2.0
# ...

# %%
# Getting a sense of how many values are missing
frame.isnull().sum()
# Out:
# Unnamed: 0                                                        0
# ZIP                                                               0
# TSP: Type of Match (Enhanced)                                     0
# Number of Children (Enhanced)                               7048450
# Family composition (Enhanced)                                  1028
# Gender code - Person 1                                        38307
# Advantage Individual Marital Status - Person 1                 1360
# Advantage Individual Marital Status Indicator - Person 1       1262
# Person Sequence Number - Person 1                              1262
# Age in 2-year ranges - Person 1 (Enhanced)                  1076820
# Target Home Market Value 2.0 Code                              1044
# Target Home Market Value 2.0 Indicator                         1044
# NICHES 5.0 Code                                                 997
# NICHES 5.0 Indicator                                            997
# ...

# %% [markdown]
# 1. 79% of the responses miss Number of Children. However, one cannot tell whether it is because the respondent does not have any, or due to missing data.
# 2.

# %%
# Some columns could use numerical value to represent. Changing A B C D into numbers
frame["Advantage Target Income 3.0"]=frame["Advantage Target Income 3.0"].replace({"A":10, "B":11,"C":12,"D":13})
frame["Discretionary Spending Income"]=frame["Discretionary Spending Income"].replace({"A":10, "B":11,"C":12})
frame["Target Net Worth 4.0 Code"]=frame["Target Net Worth 4.0 Code"].replace({"A":10, "B":11})

# %%
# Changing each columns to the right datatype
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8930770 entries, 0 to 8930769
# Data columns (total 30 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   Unnamed: 0                                                int64
#  1   ZIP                                                       int64
#  2   TSP: Type of Match (Enhanced)                             object
#  3   Number of Children (Enhanced)                             float64
#  4   Family composition (Enhanced)                             float64
#  5   Gender code - Person 1                                    float64
#  6   Advantage Individual Marital Status - Person 1            float64
#  7   Advantage Individual Marital Status Indicator - Person 1  object
#  8   Person Sequence Number - Person 1                         object
#  9   Age in 2-year ranges - Person 1 (Enhanced)                float64
# ...

# %%
data_type={"Family composition (Enhanced)":str, "Gender code - Person 1":str, "Advantage Dwelling Type":str, "Advantage Home Owner":str, "Advantage Target Income 3.0": float,"Discretionary Spending Income":float,"Target Net Worth 4.0 Code":float}
frame=frame.astype(data_type)
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8930770 entries, 0 to 8930769
# Data columns (total 30 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   Unnamed: 0                                                int64
#  1   ZIP                                                       int64
#  2   TSP: Type of Match (Enhanced)                             object
#  3   Number of Children (Enhanced)                             float64
#  4   Family composition (Enhanced)                             object
#  5   Gender code - Person 1                                    object
#  6   Advantage Individual Marital Status - Person 1            float64
#  7   Advantage Individual Marital Status Indicator - Person 1  object
#  8   Person Sequence Number - Person 1                         object
#  9   Age in 2-year ranges - Person 1 (Enhanced)                float64
# ...

# %%
#frame.to_csv(r"D:\CU\fall 2021\Practicum\df1.csv")

# %%
# taking out numerical values, and look at their correlation
num_columns=["Number of Children (Enhanced)","Age in 2-year ranges - Person 1 (Enhanced)",
             "Target Home Market Value 2.0 Code","Advantage Length of Residence","Advantage Household Age (Enhanced)",
             "Advantage Target Income 3.0","Discretionary Spending Income","Target Net Worth 4.0 Code"]
corrscore=frame[num_columns].corr()
sns.heatmap(corrscore) #seaborn
# Out:
# <AxesSubplot:>

# %%
corrscore
# Out:
#                                             Number of Children (Enhanced)  \
# Number of Children (Enhanced)                                    1.000000
# Age in 2-year ranges - Person 1 (Enhanced)                      -0.024978
# Target Home Market Value 2.0 Code                               -0.050650
# Advantage Length of Residence                                    0.155328
# Advantage Household Age (Enhanced)                              -0.032328
# Advantage Target Income 3.0                                      0.009542
# Discretionary Spending Income                                   -0.133150
# Target Net Worth 4.0 Code                                       -0.003470
#
#                                             Age in 2-year ranges - Person 1 (Enhanced)  \
# Number of Children (Enhanced)                                                -0.024978
# Age in 2-year ranges - Person 1 (Enhanced)                                    1.000000
# ...

# %% [markdown]
# 1.

# %%
# Seeing the distribution of numerical values

_,ax=plt.subplots(3,3,figsize=[20,10])

ax[0,0].hist(frame["Number of Children (Enhanced)"])
ax[0,0].set_title("Number of Children")
ax[0,1].hist(frame["Age in 2-year ranges - Person 1 (Enhanced)"])
ax[0,1].set_title("Age in 2-year ranges - Person 1")
ax[0,2].hist(frame["Target Home Market Value 2.0 Code"])
ax[0,2].set_title("Target Home Market Value 2.0 Code")
ax[1,1].hist(frame["Advantage Length of Residence"])
ax[1,1].set_title("Advantage Length of Residence")
ax[1,2].hist(frame["Advantage Household Age (Enhanced)"])
ax[1,2].set_title("Advantage Household Age")
ax[1,0].hist(frame["Advantage Target Income 3.0"])
ax[1,0].set_title("Advantage Target Income 3.0")
ax[2,0].hist(frame["Discretionary Spending Income"])
ax[2,0].set_title("Discretionary Spending Income")
ax[2,1].hist(frame["Target Net Worth 4.0 Code"])
ax[2,1].set_title("Target Net Worth 4.0 Code")
# Out:
# Text(0.5, 1.0, 'Target Net Worth 4.0 Code')

# %%
# creating a list for categorical variables
cat_columns=["Family composition (Enhanced)","Gender code - Person 1","NICHES 5.0 Code","Advantage Dwelling Type","Advantage Home Owner"]

# %%
# Seeing how each value takes up to how much for each column
for c in cat_columns:
    print(c+"")
    print(frame[c].value_counts(normalize=True))
    print()
# Out:
# Family composition (Enhanced)
# 2.0     0.285556
# 14.0    0.209368
# 12.0    0.168778
# 1.0     0.134185
# 8.0     0.048995
# 6.0     0.047606
# 4.0     0.025582
# 13.0    0.025504
# 7.0     0.023241
# 5.0     0.013052
# 11.0    0.010429
# 3.0     0.004276
# 16.0    0.002856
# 10.0    0.000377
# nan     0.000115
# 15.0    0.000068
# 9.0     0.000014
# Name: Family composition (Enhanced), dtype: float64
#
# Gender code - Person 1
# 2.0    0.533367
# 1.0    0.462175
# nan    0.004289
# 3.0    0.000168
# Name: Gender code - Person 1, dtype: float64
#
# NICHES 5.0 Code
# C3    0.093958
# B1    0.069191
# D1    0.063569
# I2    0.062478
# E3    0.051533
#         ...
# S6    0.000124
# A3    0.000118
# A7    0.000035
# A4    0.000031
# E9    0.000015
# Name: NICHES 5.0 Code, Length: 108, dtype: float64
#
# Advantage Dwelling Type
# 1.0    0.767974
# 5.0    0.129946
# 2.0    0.075348
# nan    0.020586
# 6.0    0.003844
# 3.0    0.002302
# Name: Advantage Dwelling Type, dtype: float64
#
# ...

# %%
df1=pd.read_csv(r"D:\CU\fall 2021\Practicum\df1.csv")

# %%
df1.dropna(subset=["Person Sequence Number - Person 1"],inplace=True)

# %%
df1.shape
# Out:
# (8930770, 30)

# %%
ids=df1["Person Sequence Number - Person 1"]

# %%
ids.duplicated().sum()
# Out:
# 281

# %%
pd.set_option("max_rows", 300)

# %%
df2=df1[ids.isin(ids[ids.duplicated()])]
df2.sort_values(by=["Person Sequence Number - Person 1"])
df2
# Out:
#          Unnamed: 0    ZIP TSP: Type of Match (Enhanced)  \
# 3657           3657  20001                             A
# 3658           3658  20001                             A
# 53813         53813  20002                             A
# 53814         53814  20002                             A
# 124314       124314  20008                             A
# ...             ...    ...                           ...
# 8782498     8782498  24540                             A
# 8792508     8792508  24541                             A
# 8792520     8792520  24541                             A
# 8822936     8822936  24551                             A
# 8822937     8822937  24551                             A
#
#          Number of Children (Enhanced)  Family composition (Enhanced)  \
# 3657                               NaN                            8.0
# 3658                               NaN                            8.0
# ...

# %%
df2.drop_duplicates(subset=["Person Sequence Number - Person 1"], keep="first", inplace=True, ignore_index=True)
# Out:
# <ipython-input-40-bd4fa99d8046>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop_duplicates(subset=["Person Sequence Number - Person 1"], keep="first", inplace=True, ignore_index=True)

# %%
df2["Person Sequence Number - Person 1"].duplicated().sum()
# Out:
# 0

# %%
df2.to_csv(r"C:\Users\zsk98\CU_code\course_content\Zhou_Shengkang\HW9\df1_fina.csv")

# %%
df3=df1.drop_duplicates(subset=["Person Sequence Number - Person 1"], keep="first")
df3.to_csv(r"D:\CU\fall 2021\Practicum\df1_final_version.csv")

# %%
corrscore=df3[num_columns].corr()
sns.heatmap(corrscore)
# Out:
# <AxesSubplot:>

# %%
corrscore
# Out:
#                                             Number of Children (Enhanced)  \
# Number of Children (Enhanced)                                    1.000000
# Age in 2-year ranges - Person 1 (Enhanced)                      -0.024971
# Target Home Market Value 2.0 Code                               -0.050649
# Advantage Length of Residence                                    0.155336
# Advantage Household Age (Enhanced)                              -0.032325
# Advantage Target Income 3.0                                      0.009537
# Discretionary Spending Income                                   -0.133152
# Target Net Worth 4.0 Code                                       -0.003472
#
#                                             Age in 2-year ranges - Person 1 (Enhanced)  \
# Number of Children (Enhanced)                                                -0.024971
# Age in 2-year ranges - Person 1 (Enhanced)                                    1.000000
# ...

# %%
# Seeing the distribution of numerical values

_,ax=plt.subplots(3,3,figsize=[20,10])

ax[0,0].hist(df3["Number of Children (Enhanced)"])
ax[0,0].set_title("Number of Children")
ax[0,1].hist(df3["Age in 2-year ranges - Person 1 (Enhanced)"])
ax[0,1].set_title("Age in 2-year ranges - Person 1")
ax[0,2].hist(df3["Target Home Market Value 2.0 Code"])
ax[0,2].set_title("Target Home Market Value 2.0 Code")
ax[1,1].hist(df3["Advantage Length of Residence"])
ax[1,1].set_title("Advantage Length of Residence")
ax[1,2].hist(df3["Advantage Household Age (Enhanced)"])
ax[1,2].set_title("Advantage Household Age")
ax[1,0].hist(df3["Advantage Target Income 3.0"])
ax[1,0].set_title("Advantage Target Income 3.0")
ax[2,0].hist(df3["Discretionary Spending Income"])
ax[2,0].set_title("Discretionary Spending Income")
ax[2,1].hist(df3["Target Net Worth 4.0 Code"])
ax[2,1].set_title("Target Net Worth 4.0 Code")
# Out:
# Text(0.5, 1.0, 'Target Net Worth 4.0 Code')
