# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df=pd.read_csv(r"D:\CU\fall 2021\Practicum\df20k_labeled.csv")

# %%
data=df["labels"].value_counts()
data
# Out:
# 1    7538
# 4    7199
# 0    3734
# 5    1316
# 2     202
# 3      11
# Name: labels, dtype: int64

# %%
plt.rcParams["figure.figsize"] = (20,20)
plt.rcParams['font.size'] = 30
plt.title("Cluster proportion in the sample")
pie_data=[7538, 7199, 3734, 1316, 202, 11]
labels=["1","4","0","5","2","3"]

plt.pie(x=pie_data, labels=labels,autopct='%.0f%%', explode=[0.1,0.1,0.1,0.1,0.5,0.5])
plt.show()
